# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("SQLite Test.db")

cur = conn.cursor()

# %%
df = pd.read_sql_query("SELECT * FROM dataset_1;", conn)
df.head()
# Out:
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny           55   2PM
# 1  No Urgent Place  Friend(s)   Sunny           80  10AM
# 2  No Urgent Place  Friend(s)   Sunny           80  10AM
# 3  No Urgent Place  Friend(s)   Sunny           80   2PM
# 4  No Urgent Place  Friend(s)   Sunny           80   2PM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3           Coffee House         2h  Female  21  Unmarried partner  ...
# 4           Coffee House         1d  Female  21  Unmarried partner  ...
#
#    CarryAway RestaurantLessThan20 Restaurant20To50 toCoupon_GEQ5min  \
# 0                             4~8              1~3                1
# ...

# %%
# importing sqlite3 module
import sqlite3 
# create connection by using object # to connect with hotel_data database 
connection = sqlite3.connect('SQLite Test.db') # query to create a table named FOOD1 

cursor = connection.execute("SELECT * from dataset_1 ") # display all data from hotel table 
for row in cursor:
    print(row)
# Out:
# ('No Urgent Place', 'Alone', 'Sunny', 55, '2PM', 'Restaurant(<20)', '1d', 'Female', '21', 'Unmarried partner', 1, 'Some college - no degree', 'Unemployed', '$37500 - $49999', '', 'never', 'never', '', '4~8', '1~3', 1, 0, 0, 0, 1, 1, 1)
# ('No Urgent Place', 'Friend(s)', 'Sunny', 80, '10AM', 'Coffee House', '2h', 'Female', '21', 'Unmarried partner', 1, 'Some college - no degree', 'Unemployed', '$37500 - $49999', '', 'never', 'never', '', '4~8', '1~3', 1, 0, 0, 0, 1, 0, 2)
# ('No Urgent Place', 'Friend(s)', 'Sunny', 80, '10AM', 'Carry out & Take away', '2h', 'Female', '21', 'Unmarried partner', 1, 'Some college - no degree', 'Unemployed', '$37500 - $49999', '', 'never', 'never', '', '4~8', '1~3', 1, 1, 0, 0, 1, 1, 3)
# ('No Urgent Place', 'Friend(s)', 'Sunny', 80, '2PM', 'Coffee House', '2h', 'Female', '21', 'Unmarried partner', 1, 'Some college - no degree', 'Unemployed', '$37500 - $49999', '', 'never', 'never', '', '4~8', '1~3', 1, 1, 0, 0, 1, 0, 4)
# ...

# %%
# importing sqlite3 module
import sqlite3 
connection = sqlite3.connect('SQLite Test.db') 

cursor = connection.execute("SELECT * from table_to_union ") 
for row in cursor:
    print(row)
# Out:
# ('UNION', 'UNION', 'UNION', 55, '2PM', 'Restaurant(<20)', '1d', 'Female', 21, 'Unmarried partner', 1, 'Some college - no degree', 'Unemployed', '$37500 - $49999', '', 'never', 'never', '', '4~8', '1~3', 1, 0, 0, 0, 1, 1, 1)

# %%
# importing sqlite3 module
import sqlite3 
connection = sqlite3.connect('SQLite Test.db') 

cursor = connection.execute("SELECT * from table_to_join ") 
for row in cursor:
    print(row)
# Out:
# ('2PM', 'Afternoon')
# ('10AM', 'Morning')
# ('6PM', 'Evening')
# ('7AM', 'Morning')
# ('10PM', 'Night')
